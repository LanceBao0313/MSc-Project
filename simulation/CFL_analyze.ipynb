# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

cfl_10 = pd.read_csv("./data/CFL_30device_10.csv")
cfl_05 = pd.read_csv("./data/CFL_30device_05.csv")
cfl_1 = pd.read_csv("./data/CFL_30device_1.csv")
cfl_01 = pd.read_csv("./data/CFL_30device_01.csv")

dfl_10 = pd.read_csv("./data/DFL_30device_10.csv")
dfl_05 = pd.read_csv("./data/DFL_30device_05.csv")
dfl_1 = pd.read_csv("./data/DFL_30device_1.csv")
dfl_01 = pd.read_csv("./data/DFL_30device_01.csv")
#first 6 rounds
dfl_head_10 = dfl_10[dfl_10['round'] < 7]
dfl_head_05 = dfl_05[dfl_05['round'] < 7]
dfl_head_1 = dfl_1[dfl_1['round'] < 7]
dfl_head_01 = dfl_01[dfl_01['round'] < 7]
# cfl_05

# %%
# preprocess
loss_round_cfl_10 = cfl_10.groupby('round')['train_loss'].mean().reset_index()
loss_round_cfl_05 = cfl_05.groupby('round')['train_loss'].mean().reset_index()
loss_round_cfl_1 = cfl_1.groupby('round')['train_loss'].mean().reset_index()
loss_round_cfl_01 = cfl_01.groupby('round')['train_loss'].mean().reset_index()
acc_cfl_10 = [0, 0.8112,0.8166,0.8171,0.8181,0.8184,0.8190]
f1_cfl_10 = [0, 0.89575, 0.89904, 0.899345, 0.89995, 0.900131, 0.90049]
acc_cfl_05 = [0, 0.8006,0.8126,0.8138,0.8147,0.8147,0.8155]
f1_cfl_05 = [0, 0.88925, 0.89661,0.897342,0.89788,0.897889,0.898375]
acc_cfl_1 = [0, 0.8084,0.8136,0.8157,0.8157,0.8161,0.817]
f1_cfl_1 = [0, 0.89404, 0.89722,0.898496,0.89849,0.898739,0.899284]
acc_cfl_01 = [0, 0.7054,0.7729,0.7785,0.7805,0.7750,0.7729]
f1_cfl_01 = [0, 0.82725, 0.87190,0.87545,0.876720,0.873239,0.871904]

loss_round_dfl_10 = dfl_head_10.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_05 = dfl_head_05.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_1 = dfl_head_1.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_01 = dfl_head_01.groupby('round')['train_loss'].mean().reset_index()
acc_dfl_10 = [0, 0.1491,0.7258, 0.7292,0.7710,0.7965,0.8055,0.8072,0.8082,0.8089,0.8094,0.8096, 0.8102,0.8102]
f1_dfl_10 = [0, 0.2548,0.8410, 0.8434,0.8707,0.8867,0.8923,0.8933,0.8939,0.8943,0.8946,0.8948,0.8951,0.8952]
time_dfl_10 = [0, 108,215,322,428,535,641,748,854,961,1067,1173,1279,1385]
acc_dfl_05 = [0, 0.1361,0.5359,0.6224,0.6745,0.7019,0.7157,0.7216,0.7293,0.7310,0.7321,0.7358,0.7378,0.7364 ]
f1_dfl_05 = [0, 0.2366,0.6956,0.7663,0.8053,0.8246,0.8341,0.8381,0.8432,0.8444,0.8451,0.8476,0.8489,0.8480]
time_dfl_05 = [0, 106,212,317,421,525,629,734,838,942,1047,1151,1256,1361]
acc_dfl_1 = [0, 0.1592,0.6213,0.6451,0.7006,0.7347,0.7529,0.7598,0.7637,0.7638,0.7652,0.7657,0.7656,0.7659]
f1_dfl_1 = [0, 0.2691,0.7655,0.7839,0.8237,0.8469,0.8589,0.8634,0.8659,0.8659,0.8669,0.8672,0.8671,0.8673]
time_dfl_1 = [0, 106,212,318,423,528,633,738,844,949,1054,1160,1266,1371]
acc_dfl_01 = [0, 0.1266,0.2541,0.3346,0.4005,0.4436,0.4732,0.5087,0.5301,0.5626,0.5739,0.6038,0.6190,0.6281,0.6404,0.6331,0.6453,0.6568,0.6586]
f1_dfl_01 = [0, 0.2227,0.4014,0.4981,0.5704,0.6135,0.6416,0.6730,0.6912,0.7184,0.7279,0.7522,0.7638,0.7711,0.7804,0.7748,0.7838,0.7924,0.7935]
time_dfl_01 = [0, 105,210,316,421,526,631,736,840,945,1050,1154,1260,1366,1471,1578,1684,1789,1894]


# pd.concat([pd.Series([0]), avg_loss_per_round['train_loss']])

# %%
plt.figure(figsize=(10, 6))
plt.plot(loss_round_cfl_10['round'], loss_round_cfl_10['train_loss'], marker='o', linestyle='-', color='b')
plt.plot(loss_round_dfl_10['round'], loss_round_dfl_10['train_loss'], marker='o', linestyle='-', color='r')
plt.plot(loss_round_cfl_1['round'], loss_round_cfl_1['train_loss'], marker='o', linestyle='-.', color='b')
plt.plot(loss_round_dfl_1['round'], loss_round_dfl_1['train_loss'], marker='o', linestyle='-.', color='r')
plt.plot(loss_round_cfl_05['round'], loss_round_cfl_05['train_loss'], marker='^', linestyle='--', color='g')
plt.plot(loss_round_dfl_05['round'], loss_round_dfl_05['train_loss'], marker='^', linestyle='--', color='y')
plt.plot(loss_round_cfl_01['round'], loss_round_cfl_01['train_loss'], marker='^', linestyle=':', color='g')
plt.plot(loss_round_dfl_01['round'], loss_round_dfl_01['train_loss'], marker='^', linestyle=':', color='y')


plt.ylim(0, 0.02)
plt.xlabel('Rounds', fontsize=20)
plt.legend(['CFL alpha=10', 'DFL alpha=10','CFL alpha=1','DFL alpha=1', 'CFL alpha=0.5','DFL alpha=0.5','CFL alpha=0.1','DFL alpha=0.1'], fontsize=17)
plt.ylabel('Average Train Loss', fontsize=20)
plt.title('Average Train Loss vs. Rounds', fontsize=20)
plt.grid(True)
plt.savefig('../graphs/loss_rounds_30device_alpha.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(range(7), acc_cfl_10, marker='o', linestyle='-', color='b')
plt.plot(range(len(acc_dfl_10)), acc_dfl_10, marker='o', linestyle='-', color='r')
plt.plot(range(7), acc_cfl_1, marker='o', linestyle='-.', color='b')
plt.plot(range(len(acc_dfl_1)), acc_dfl_1, marker='o', linestyle='-.', color='r')
plt.plot(range(7), acc_cfl_05, marker='^', linestyle='--', color='g')
plt.plot(range(len(acc_dfl_05)), acc_dfl_05, marker='^', linestyle='--', color='y')
plt.plot(range(7), acc_cfl_01, marker='^', linestyle=':', color='g')
plt.plot(range(len(acc_dfl_01)), acc_dfl_01, marker='^', linestyle=':', color='y')

# plt.ylim(0, 0.05)
plt.xlabel('Rounds', fontsize=20)
plt.ylabel('Average Accuracy', fontsize=20)
plt.title('Average Accuracy vs. Rounds', fontsize=20)
plt.legend(['CFL alpha=10', 'DFL alpha=10','CFL alpha=1', 'DFL alpha=1','CFL alpha=0.5', 'DFL alpha=0.5','CFL alpha=0.1', 'DFL alpha=0.1'], fontsize=17)
plt.grid(True)
plt.savefig('../graphs/acc_rounds_30device_alpha.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(7), f1_cfl_10, marker='o', linestyle='-', color='b')
plt.plot(range(len(f1_dfl_10)), f1_dfl_10, marker='o', linestyle='-', color='r')
plt.plot(range(7), f1_cfl_1, marker='o', linestyle='-.', color='b')
plt.plot(range(len(f1_dfl_1)), f1_dfl_1, marker='o', linestyle='-.', color='r')
plt.plot(range(7), f1_cfl_05, marker='^', linestyle='--', color='g')
plt.plot(range(len(f1_dfl_05)), f1_dfl_05, marker='^', linestyle='--', color='y')
plt.plot(range(7), f1_cfl_01, marker='^', linestyle=':', color='g')
plt.plot(range(len(f1_dfl_01)), f1_dfl_01, marker='^', linestyle=':', color='y')
# plt.ylim(0, 0.05)
plt.xlabel('Rounds', fontsize=20)
plt.ylabel('Average F1-score', fontsize=20)
plt.title('Average F1-score vs. Rounds', fontsize=20)
plt.legend(['CFL alpha=10', 'DFL alpha=10','CFL alpha=1', 'DFL alpha=1','CFL alpha=0.5', 'DFL alpha=0.5','CFL alpha=0.1', 'DFL alpha=0.1'], fontsize=17)
plt.grid(True)
plt.savefig('../graphs/f1_rounds_30device_alpha.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
time_10 = [cfl_10.iloc[i*29]['wall_clock_time'] for i in range(7)]
time_1 = [cfl_1.iloc[i*29]['wall_clock_time'] for i in range(7)]
time_05 = [cfl_05.iloc[i*29]['wall_clock_time'] for i in range(7)]
time_01 = [cfl_01.iloc[i*29]['wall_clock_time'] for i in range(7)]

time_10[0] = 0
time_1[0] = 0
time_05[0] = 0
time_01[0] = 0

plt.figure(figsize=(10, 6))

plt.plot(time_10, acc_cfl_10, marker='o', linestyle='-', color='b')
plt.plot(time_dfl_10, acc_dfl_10, marker='o', linestyle='-', color='r')
plt.plot(time_1, acc_cfl_1, marker='o', linestyle='-.', color='b')
plt.plot(time_dfl_1, acc_dfl_1, marker='o', linestyle='-.', color='r')
plt.plot(time_05, acc_cfl_05, marker='^', linestyle='--', color='g')
plt.plot(time_dfl_05, acc_dfl_05, marker='^', linestyle='--', color='y')
plt.plot(time_01, acc_cfl_01, marker='^', linestyle=':', color='g')
plt.plot(time_dfl_01, acc_dfl_01, marker='^', linestyle=':', color='y')

plt.xlabel('Wall-Clock Time (s)', fontsize=20)
plt.ylabel('Average Accuracy', fontsize=20)
plt.title('Average Accuracy vs. Wall-Clock Time', fontsize=20)
plt.legend(['CFL alpha=10', 'DFL alpha=10','CFL alpha=1', 'DFL alpha=1','CFL alpha=0.5', 'DFL alpha=0.5','CFL alpha=0.1', 'DFL alpha=0.1'], fontsize=17)
plt.grid(True)
plt.savefig('../graphs/acc_time_30device_alpha.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
dfl_01_acc = pd.read_csv("./data/alpha_01.csv")
dfl_01_sample = dfl_01[dfl_01['round'] == 18][['device_id','num_train_samples']]
dfl_01_full = pd.merge(dfl_01_sample, dfl_01_acc, on='device_id')
dfl_01_full
# Out:
#     device_id  num_train_samples  accuracy      f1
# 0          27                928    0.6602  0.7953
# 1          19                 34    0.6961  0.8208
# 2           1                456    0.6696  0.8021
# 3           0               2855    0.6449  0.7841
# 4          28               1002    0.6752  0.8061
# 5          11               1122    0.6354  0.7771
# 6           9               2355    0.6787  0.8086
# 7           6                219    0.6254  0.7695
# 8          29               2097    0.6503  0.7881
# 9          22               4263    0.7224  0.8388
# 10         13               3518    0.6644  0.7984
# 11          3                467    0.6358  0.7774
# 12          8                240    0.6272  0.7709
# 13          5                579    0.6529  0.7900
# 14         18                977    0.6123  0.7595
# 15         20               1909    0.6474  0.7860
# 16         15               2530    0.6577  0.7935
# ...

# %%
# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(dfl_01_full['num_train_samples'], dfl_01_full['accuracy'], color='blue')
plt.xlabel('Number of Samples')
plt.ylabel('Accuracy')
plt.title('Relationship Between Number of Samples and Model Accuracy')
plt.grid(True)
plt.show()

# %%
# Number of devices impacts
cfl_30 = pd.read_csv("./data/CFL_30device_balance.csv")
cfl_60 = pd.read_csv("./data/CFL_60device_balance.csv")
cfl_100 = pd.read_csv("./data/CFL_100device_balance.csv")
dfl_30 = pd.read_csv("./data/DFL_30device_balance.csv")
dfl_60 = pd.read_csv("./data/DFL_60device_balance_2.csv")
dfl_100 = pd.read_csv("./data/DFL_100device_balance.csv")
dfl_100_gossip = pd.read_csv("./data/DFL_100device_balance_gossip.csv")
dlf_100_local = pd.read_csv("./data/DFL_100device_balance_local.csv")

loss_round_cfl_30 = cfl_30.groupby('round')['train_loss'].mean().reset_index()
loss_round_cfl_60 = cfl_60.groupby('round')['train_loss'].mean().reset_index()
loss_round_cfl_100 = cfl_100.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_30 = dfl_30.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_60 = dfl_60.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_100 = dfl_100.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_100_gossip = dfl_100_gossip.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_100_local = dlf_100_local.groupby('round')['train_loss'].mean().reset_index()

acc_cfl_30 = [0, 0.8096,0.8175,0.8191,0.8191,0.8187,0.8189]
acc_cfl_60 = [0,0.7615,0.8089,0.814,0.8166,0.8169,0.8178]
f1_cfl_60 = [0,0.86460,0.894355,0.8974,0.8990,0.8992,0.8998]
acc_cfl_100 = [0,0.7627,0.8093,0.8149,0.8163,0.8168,0.8183]
f1_cfl_100 = [0,0.8653,0.8946,0.8980,0.8988,0.8991,0.9000]

acc_dfl_30 = [0, 0.1167, 0.7897,0.7939,0.8046,0.8065,0.8083,0.8099,0.8095]
f1_dfl_30 = [0,0.2083, 0.8825,0.8851,0.8917, 0.8929, 0.8940,0.8949,0.8947]
time_dfl_30 = [0,109,218, 294, 391, 488,584,680,779]

acc_dfl_60_60 = [0,0.1203,0.5633,0.7827,0.8085,0.8126,0.8140,0.8148]
f1_dfl_60_60 = [0,0.2137,0.7199, 0.8781,0.8941,0.8966,0.8975,0.8980]
time_dfl_60_60 = [0,142,287,569,710,851,992,1134]
acc_dfl_100 = [0,0.0984,0.6791,0.5593,0.4921,0.5243,0.5746,0.6120,0.6944,0.7357,0.7548,0.7674,0.7827,0.7958, 0.8025,0.8052]
f1_dfl_100 = [0,0.1758,0.8086,0.7169,0.6594,0.6878,0.7298,0.7593,0.8196,0.8477,0.8603,0.8684,0.8781,0.8863,0.8904,0.8921]
time_dfl_100 = [0,298,594,891,1186,1482,1777,2073,2370,2666,2962,3257,3554,3850,4146,4442]
acc_dfl_100_gossip = [0,0.1032, 0.6841,0.5409,0.4820,0.5235,0.5845,0.6274,0.7121,0.7493,0.7679,0.7785,0.7889,0.7985,0.8040,0.8064,0.8079]
f1_dfl_100_gossip = [0,0.1839,0.8123,0.7015,0.6501,0.6870,0.7377,0.7710,0.8318,0.8567,0.8687,0.8754,0.8820,0.8880,0.8913,0.8928,0.8938]
time_dfl_100_gossip = [0,309,613,916,1221,1525,1828,2132,2435,2738,3045,3348,3652,3957,4262,4566,4869]
acc_dfl_100_local = [0,0.1001,0.5666,0.4354,0.5709,0.7115,0.7557,0.7887,0.8029,0.8065,0.8082]
f1_dfl_100_local = [0,0.1806,0.7217,0.6063,0.7268,0.8314,0.8609,0.8818,0.8907,0.8929,0.8939]
time_dfl_100_local = [0,223,425,628,831,1033,1235,1441,1643,1841,2042]

# %%
plt.figure(figsize=(10, 6))

plt.plot(range(len(acc_cfl_30)), acc_cfl_30, marker='^', linestyle='-', color='r')
plt.plot(range(len(acc_cfl_60)), acc_cfl_60, marker='^', linestyle='-', color='y')
plt.plot(range(len(acc_cfl_100)), acc_cfl_100, marker='^', linestyle='-', color='g')
# plt.plot(range(7), acc_cfl_1, marker='o', linestyle='-.', color='b')
# plt.plot(range(7), acc_cfl_05, marker='^', linestyle='--', color='g')
# plt.plot(range(7), acc_cfl_01, marker='^', linestyle=':', color='g')
plt.plot(range(len(acc_dfl_30)), acc_dfl_30, marker='o', linestyle='-', color='r')
plt.plot(range(len(acc_dfl_60_60)), acc_dfl_60_60, marker='o', linestyle='-.', color='y')
plt.plot(range(len(acc_dfl_100)), acc_dfl_100, marker='o', linestyle='--', color='g')
# plt.plot(range(len(acc_dfl_100_gossip)), acc_dfl_100_gossip, marker='*', linestyle='-', color='purple')

# plt.plot(range(len(acc_dfl_01)), acc_dfl_01, marker='^', linestyle=':', color='y')

# plt.ylim(0, 0.05)
plt.xlabel('Rounds', fontsize=20)
plt.ylabel('Average Accuracy', fontsize=20)
plt.title('Average Accuracy vs. Rounds', fontsize=20)
plt.legend(['CFL 30 devices','CFL 60 devices','CFL 100 devices','DFL 30 devices', 'DFL 60 devices','DFL 100 devices'], fontsize=17)
plt.grid(True)
plt.savefig('../graphs/acc_rounds_num_device.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(loss_round_cfl_30['round'], loss_round_cfl_30['train_loss'], marker='^', linestyle='-', color='r')
plt.plot(loss_round_cfl_60['round'], loss_round_cfl_60['train_loss'], marker='^', linestyle='-', color='y')
plt.plot(loss_round_cfl_100['round'], loss_round_cfl_100['train_loss'], marker='^', linestyle='-.', color='g')
plt.plot(loss_round_dfl_30['round'], loss_round_dfl_30['train_loss'], marker='o', linestyle='-', color='r')
plt.plot(loss_round_dfl_60['round'], loss_round_dfl_60['train_loss'], marker='o', linestyle='-', color='y')
plt.plot(loss_round_dfl_100['round'], loss_round_dfl_100['train_loss'], marker='o', linestyle='-.', color='g')


plt.ylim(0, 0.02)
plt.xlabel('Rounds', fontsize=20)
plt.legend(['CFL 30 devices','CFL 60 devices','CFL 100 devices','DFL 30 devices', 'DFL 60 devices','DFL 100 devices'], fontsize=17)
plt.ylabel('Average Train Loss', fontsize=20)
plt.title('Average Train Loss vs. Rounds', fontsize=20)
plt.grid(True)
plt.savefig('../graphs/loss_rounds_30device_num_device.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
acc_dfl_100_75 = [0,0.0783,0.6563,0.4893,0.5471,0.6117,0.7269,0.7630,0.7816,0.7971,0.8048]
f1_dfl_100_75 = [0,0.1437,0.7924,0.6568,0.7071,0.7590,0.8419,0.8656,0.8774,0.8871,0.8919]
time_dfl_100_75 = [0,223,425,628,831,1033,1235,1441,1643,1841,2042]
acc_dfl_100_gossip500 = [0,0.1018,0.6464,0.4126,0.5205,0.5968,0.7136,0.7608,0.7791,0.7938,0.8032,0.8065,0.8077]


acc_dfl_100_30 = [0,0.1358,0.5444,0.3393,0.3098,0.4133,0.4984,0.5942,0.6679,0.7267,0.7647,0.7800,0.7881,0.7976,0.8031,0.8060]
f1_dfl_100_30 = [0,0.2316,0.7011,0.5019,0.4712,0.5840,0.6650,0.7453,0.8007,0.8416,0.8666,0.8764,0.8815,0.8874,0.8908,0.8926]
time_dfl_100_30 = [0,223,425,628,831,1033,1235,1441,1643,1841,2042]

acc_dfl_100_ultimate = [0,0.0942,0.6036,0.5214,0.6075,0.7421,0.7729,0.7966,0.8051,0.8077,0.8088]

plt.figure(figsize=(10, 6))
plt.plot(range(len(acc_dfl_100)), acc_dfl_100, marker='*', linestyle='-', color='g')
plt.plot(range(len(acc_dfl_100_gossip)), acc_dfl_100_gossip, marker='*', linestyle='-', color='purple')
plt.plot(range(len(acc_dfl_100_gossip500)), acc_dfl_100_gossip500, marker='*', linestyle='-', color='yellow')
plt.plot(range(len(acc_dfl_100_local)), acc_dfl_100_local, marker='*', linestyle='-', color='orange')
plt.plot(range(len(acc_dfl_100_75)), acc_dfl_100_75, marker='*', linestyle='-', color='blue')
plt.plot(range(len(acc_dfl_100_30)), acc_dfl_100_30, marker='*', linestyle='-', color='black')
plt.plot(range(len(acc_dfl_100_ultimate)), acc_dfl_100_ultimate, marker='^', linestyle='--', color='red')


# plt.plot(range(len(acc_dfl_01)), acc_dfl_01, marker='^', linestyle=':', color='y')

# plt.ylim(0, 0.05)
plt.xlabel('Rounds', fontsize=20)
plt.ylabel('Average Accuracy', fontsize=20)
plt.title('Average Accuracy vs. Rounds under different configurations', fontsize=20)
plt.legend(['DFL with 100 devices (baseline)','Gossip rounds = 50', 'Gossip rounds=250','More local training epochs','Range=75','Range=30','Optimial Setting'], fontsize=17)
plt.grid(True)
plt.savefig('../graphs/acc_rounds_100device_all.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
acc_dfl_60_15 = [0,0.1133,0.4501,0.5336,0.6335,0.7051,0.7348,0.7669,0.8071,0.7741,0.7777, 0.7594,0.8117,0.7757,0.7958]
f1_dfl_60_15 = [0,0.2096,0.5433,0.6501,0.7298,0.8070,0.8229,0.8521, 0.8932,0.8566,0.8624,0.8425,0.8961,0.8575,0.8818]
time_dfl_60_15 = [0,188,375,562,747,934,1120,1307,1494,1681,1867,2054,2241,2427]

acc_dfl_60_30 = [0,0.1297,0.5505,0.6254,0.7128,0.7511,0.7982,0.8113]
f1_dfl_60_30 = [0,0.2141,0.6829,0.7198,0.8017,0.8433,0.8839,0.8958]
time_dfl_60_30 = [0,194,385,574,765,956,1148,1339]

acc_dfl_60_45 = [0,0.1176,0.5192,0.7008,0.7634,0.8013,0.8115,0.8134,0.8148]
f1_dfl_60_45 = [0,0.2087,0.6818, 0.8241,0.8658,0.8897,0.8959,0.8971,0.8980]
time_dfl_60_45 = [0,142,284,424,564,705,848,989,1132]

acc_dfl_60_60 = [0,0.1203,0.5633,0.7827,0.8085,0.8126,0.8140,0.8148]
f1_dfl_60_60 = [0,0.2137,0.7199, 0.8781,0.8941,0.8966,0.8975,0.8980]
time_dfl_60_60 = [0,142,287,569,710,851,992,1134]

acc_dfl_60_75 = [0,0.1098,0.5348,0.7551,0.7958,0.8103,0.8124,0.8141]
f1_dfl_60_75 = [0,0.1975,0.6959, 0.8605,0.8863,0.8952,0.8965,0.8975]
time_dfl_60_75 = [0,163,324,484,644,808,1010,1215]

acc_dfl_60_90 = [0,0.1058,0.5513,0.7615,0.7983,0.8107,0.8131,0.8139]
f1_dfl_60_90 = [0,0.1911,0.7093, 0.8646,0.8879,0.8954,0.8969,0.8974]
time_dfl_60_90 = [0,215,456,618,759,901,1042,1182]

plt.figure(figsize=(10, 6))
plt.plot(range(len(acc_dfl_60_15)), acc_dfl_60_15, marker='*', linestyle='-', color='g')
plt.plot(range(len(acc_dfl_60_30)), acc_dfl_60_30, marker='*', linestyle='-', color='purple')
plt.plot(range(len(acc_dfl_60_45)), acc_dfl_60_45, marker='*', linestyle='-', color='orange')
plt.plot(range(len(acc_dfl_60_60)), acc_dfl_60_60, marker='*', linestyle='-', color='red')
plt.plot(range(len(acc_dfl_60_75)), acc_dfl_60_75, marker='*', linestyle='-', color='blue')
plt.plot(range(len(acc_dfl_60_90)), acc_dfl_60_90, marker='*', linestyle='-', color='pink')

# plt.ylim(0, 0.05)
plt.xlabel('Rounds', fontsize=20)
plt.ylabel('Average Accuracy', fontsize=20)
plt.title('Average Accuracy vs. Rounds with different communication range', fontsize=20)
plt.legend(['range=15','range=30', 'range=45','range=60', 'range=75', 'range=90'], fontsize=17)
plt.grid(True)
plt.savefig('../graphs/acc_rounds_range.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
dfl_60_15 = pd.read_csv("./data/DFL_60device_balance_range_15.csv")
dfl_60_30 = pd.read_csv("./data/DFL_60device_balance_range_30.csv")
dfl_60_45 = pd.read_csv("./data/DFL_60device_balance_range_45.csv")
dfl_60_60 = pd.read_csv("./data/DFL_60device_balance_range_60.csv")
dfl_60_75 = pd.read_csv("./data/DFL_60device_balance_range_75.csv")
dfl_60_90 = pd.read_csv("./data/DFL_60device_balance_range_90.csv")

loss_round_dfl_60_15 = dfl_60_15.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_60_30 = dfl_60_30.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_60_45 = dfl_60_45.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_60_60 = dfl_60_60.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_60_75 = dfl_60_75.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_60_90 = dfl_60_90.groupby('round')['train_loss'].mean().reset_index()


plt.figure(figsize=(10, 6))
plt.plot(loss_round_dfl_60_15['round'], loss_round_dfl_60_15['train_loss'], marker='*', linestyle='-', color='g')
plt.plot(loss_round_dfl_60_30['round'], loss_round_dfl_60_30['train_loss'], marker='*', linestyle='-', color='purple')
plt.plot(loss_round_dfl_60_45['round'], loss_round_dfl_60_45['train_loss'], marker='*', linestyle='-', color='orange')
plt.plot(loss_round_dfl_60_60['round'], loss_round_dfl_60_60['train_loss'], marker='*', linestyle='-', color='red')
plt.plot(loss_round_dfl_60_75['round'], loss_round_dfl_60_75['train_loss'], marker='*', linestyle='-', color='blue')
plt.plot(loss_round_dfl_60_90['round'], loss_round_dfl_60_90['train_loss'], marker='*', linestyle='-', color='pink')
plt.xlabel('Rounds', fontsize=20)
plt.ylabel('Average Train Loss', fontsize=20)
plt.title('Average Train Loss vs. Rounds with different communication range', fontsize=20)
plt.legend(['range=15','range=30', 'range=45','range=60', 'range=75', 'range=90'], fontsize=17)
plt.grid(True)
plt.savefig('../graphs/loss_rounds_range.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
acc_dfl_60_alpha05_range15 = [0,0.1090,0.3424,0.4287,0.4546,0.5330,0.5322,0.5565,0.5688,0.5680,0.5851,0.5840,0.6148,0.6446, 0.6232,0.6252]
f1_dfl_alpha05_range15 =     [0,0.1890,0.4950,0.5809,0.6089,0.6898,0.6783,0.7057,0.7165,0.7076,0.7320,0.7235,0.7563,0.7782,0.7466,0.7622]
time_dfl_alpha05_range15 =   [0,122   ,243   ,364   ,485   ,606   ,726   ,847   ,967,   1086   ,1206, 1326,  1447, 1567,1687,1810]

acc_dfl_60_alpha05_range30 = [0,0.1325,0.4356,0.4830,0.5389,0.5622,0.6043,0.6302,0.6484,0.6749,0.6899,0.7051,0.7141,0.7183,0.7200]
f1_dfl_alpha05_range30 =     [0,0.2299,0.5998,0.6450,0.6975,0.7167,0.7518,0.7723,0.7863,0.8054,0.8160,0.8267,0.8328,0.8358,0.8368]
time_dfl_alpha05_range30 =   [0,122   ,243   ,368   ,491   ,614   ,740   ,865   ,988,   1111   ,1235,1358,1480,1616,]

acc_dfl_60_alpha05_range45 = [0,0.1533,0.3292,0.4695,0.5733,0.6340,0.6619,0.6897,0.7011,0.7177,0.7162,0.7291,0.7224]
f1_dfl_alpha05_range45 =     [0,0.2609,0.4861,0.6364,0.7284,0.7757,0.7960,0.8160,0.8240,0.8353,0.8343,0.8431,0.8386]
time_dfl_alpha05_range45 =   [0,122   ,243   ,364   ,491   ,614   ,740   ,865   ,988,   1111   ,1235,1358,1480]

acc_dfl_60_alpha05_range60 = [0,0.1466,0.3143,0.4891,0.5974,0.6332,0.6841,0.7012,0.7135,0.7229,0.7222,0.7282,0.7279]
f1_dfl_alpha05_range60 = [0,0.2529,0.4674,0.6550,0.7472,0.7750,0.8119,0.8241,0.8325,0.8389,0.8385,0.8426,0.8423]
time_dfl_alpha05_range60 = [0,124,246,368,491,614,740,865,988,1111,1235,1358,1480]

acc_dfl_60_alpha05_range75 = [0,0.1585,0.3934,0.4785,0.5429,0.6354,0.6739,0.6935,0.7138,0.7227,0.7245,0.7323,0.7310,0.7362]
f1_dfl_alpha05_range75 =     [0,0.2715,0.5630,0.6467,0.7033,0.7763,0.8045,0.8186,0.8327,0.8388,0.8401,0.8454,0.8444,0.8479]
time_dfl_alpha05_range75 =   [0,122   ,243   ,364   ,491   ,614   ,740   ,865   ,988,   1111   ,1235, 1358, 1480, 1611]

acc_dfl_60_alpha05_range90 = [0,0.1591,0.4592,0.5323,0.5971,0.6518,0.6834,0.7086,0.7169,0.7260,0.7282,0.7288,0.7292,0.7377,0.7274]
f1_dfl_alpha05_range90 =     [0,0.2727,0.6258,0.6941,0.7474,0.7887,0.8115,0.8291,0.8348,0.8411,0.8425,0.8429,0.8432,0.8489,0.8419]
time_dfl_alpha05_range90 =   [0,122   ,243   ,364   ,491   ,614   ,740   ,865   ,988,   1111   ,1235,1358,1480,1588,1710]

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(len(acc_dfl_60_alpha05_range15)), acc_dfl_60_alpha05_range15, marker='*', linestyle='-', color='g')
plt.plot(range(len(acc_dfl_60_alpha05_range30)), acc_dfl_60_alpha05_range30, marker='*', linestyle='-', color='purple')
plt.plot(range(len(acc_dfl_60_alpha05_range45)), acc_dfl_60_alpha05_range45, marker='*', linestyle='-', color='orange')
plt.plot(range(len(acc_dfl_60_alpha05_range60)), acc_dfl_60_alpha05_range60, marker='*', linestyle='-', color='red')
plt.plot(range(len(acc_dfl_60_alpha05_range75)), acc_dfl_60_alpha05_range75, marker='*', linestyle='-', color='blue')
plt.plot(range(len(acc_dfl_60_alpha05_range90)), acc_dfl_60_alpha05_range90, marker='*', linestyle='-', color='pink')

# plt.ylim(0, 0.05)
plt.xlabel('Rounds', fontsize=20)
plt.ylabel('Average Accuracy', fontsize=20)
plt.title('Average Accuracy vs. Rounds with different communication range (alpha=0.5)', fontsize=17)
plt.legend(['range=15','range=30', 'range=45','range=60', 'range=75', 'range=90'], fontsize=17)
plt.grid(True)
plt.savefig('../graphs/acc_rounds_alpha_range.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
dfl_60_15 = pd.read_csv("./data/DFL_60device_05_15.csv")
dfl_60_30 = pd.read_csv("./data/DFL_60device_05_30.csv")
dfl_60_30 = dfl_60_30[dfl_60_30['round'] < 18]
dfl_60_45 = pd.read_csv("./data/DFL_60device_05_45.csv")
dfl_60_60 = pd.read_csv("./data/DFL_60device_05_60.csv")
dfl_60_75 = pd.read_csv("./data/DFL_60device_05_75.csv")
dfl_60_90 = pd.read_csv("./data/DFL_60device_05_90.csv")

loss_round_dfl_60_15 = dfl_60_15.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_60_30 = dfl_60_30.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_60_45 = dfl_60_45.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_60_60 = dfl_60_60.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_60_75 = dfl_60_75.groupby('round')['train_loss'].mean().reset_index()
loss_round_dfl_60_90 = dfl_60_90.groupby('round')['train_loss'].mean().reset_index()


plt.figure(figsize=(10, 6))
plt.plot(loss_round_dfl_60_15['round'], loss_round_dfl_60_15['train_loss'], marker='*', linestyle='-', color='g')
plt.plot(loss_round_dfl_60_30['round'], loss_round_dfl_60_30['train_loss'], marker='*', linestyle='-', color='purple')
plt.plot(loss_round_dfl_60_45['round'], loss_round_dfl_60_45['train_loss'], marker='*', linestyle='-', color='orange')
plt.plot(loss_round_dfl_60_60['round'], loss_round_dfl_60_60['train_loss'], marker='*', linestyle='-', color='red')
plt.plot(loss_round_dfl_60_75['round'], loss_round_dfl_60_75['train_loss'], marker='*', linestyle='-', color='blue')
plt.plot(loss_round_dfl_60_90['round'], loss_round_dfl_60_90['train_loss'], marker='*', linestyle='-', color='pink')
plt.xlabel('Rounds', fontsize=20)
plt.ylabel('Average Train Loss', fontsize=20)
plt.title('Average Train Loss vs. Rounds with different communication range (alpha=0.5)', fontsize=17)
plt.legend(['range=15','range=30', 'range=45','range=60', 'range=75', 'range=90'], fontsize=17)
plt.grid(True)
plt.savefig('../graphs/loss_rounds_05_range.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
emd = [0, 0.1428,0.5361,0.4788,0.5369,0.6039,0.6352,0.6612,0.6763,0.6888,0.6985,0.7114,0.7179,0.7251,0.7286,0.7290,0.7302,0.7318,0.7299,0.7318]
layer = [0,0.1654,0.4318,0.4686,0.5554,0.6019,0.6413,0.6559,0.6694,0.6856,0.6996,0.7162,0.7214,0.7227,0.7218]
baseline = [0,0.1466,0.3143,0.4891,0.5974,0.6332,0.6841,0.7012,0.7135,0.7229,0.7222,0.7282,0.7279]




plt.figure(figsize=(10, 6))
plt.plot(range(len(emd)), emd, marker='*', linestyle='-', color='g')
plt.plot(range(len(layer)), layer, marker='*', linestyle='-', color='purple')
plt.plot(range(len(baseline)), baseline, marker='.', linestyle='-', color='red')

# plt.ylim(0, 0.05)
plt.xlabel('Rounds', fontsize=20)
plt.ylabel('Average Accuracy', fontsize=20)
plt.title('Average Accuracy vs. Rounds with different communication range (alpha=0.5)', fontsize=17)
plt.legend(['EMD','1-layer GD-PSGD'], fontsize=17)
plt.grid(True)
# plt.savefig('../graphs/acc_rounds_alpha_range.png', dpi=300, bbox_inches='tight')
plt.show()
